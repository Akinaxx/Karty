# %%
<table>
    <tbody>
        <tr>
            <th style="text-align:right;width:18%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Imię i nazwisko:</span></span></th>
            <td style="text-align:center;width:25%">
                <p style="line-height: 50%">Imie</p>
                <p style="line-height: 50%">Nazwisko</p>
            </td>
            <th style="text-align:right;width:8%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Wiek</span></span>:</th>
            <td style="text-align:center;width:7.5%">?</td>
            <th style="text-align:right;width:7.5%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Płeć</span></span>:</th>
            <td style="text-align:center;width:10%">?</td>
            <th style="text-align:right;width:10%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Profesja</span></span>:</th>
            <td style="text-align:center;width:15%">?</td>
        </tr>
        <tr>
            <th style="text-align:right;width:18%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Miejsce pochodzenia:</span></span></th>
            <td style="text-align:center;width:25%">?</td>
            <th style="text-align:right;width:8%"></th>
            <td style="text-align:center;width:7.5%"></td>
            <th style="text-align:right;width:7.5%"></th>
            <td style="text-align:center;width:10%"></td>
            <th style="text-align:right;width:10%"></th>
            <td style="text-align:center;width:15%"></td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <td style="text-align:right"></td>
            <td style="text-align:left"></td>
            <th style="text-align:center">Rany i obrażenia</th>
            <td style="text-align:right"></td>
            <td style="text-align:left"></td>
        </tr>
        <tr>
            <th style="text-align:center;width:32%">Pomniejsze</th>
            <td style="text-align:left;width:2.5%"></td>
            <th style="text-align:center;width:32%">Poważne</th>
            <td style="text-align:left;width:2.5%"></td>
            <th>Śmiertelne</th>
        </tr>
        <tr>
            <td style="text-align:center">Brak</td>
            <td style="text-align:center"></td>
            <td style="text-align:center">Brak</td>
            <td style="text-align:center"></td>
            <td style="text-align:center">Brak</td>
        </tr>
        <tr>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
        </tr>
        <tr>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
            <td style="text-align:center"></td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th></th>
            <th style="text-align:right">Cechy_</th>
            <th style="text-align:left">Bohatera</th>
            <th></th>
        </tr>
        <tr>
            <th>Siła</th>
            <th>Zręczność</th>
            <th>Kondycja</th>
            <th>Budowa Ciała</th>
        </tr>
        <tr>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@cecha_sila)df20 #</p>
                <h2>Test Siły</h2>
                <p>#SIŁ}}{{@cecha_sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@cecha_zrecznosc)df20 #</p>
                <h2>Test Zręczności</h2>
                <p>#ZR}}{{@cecha_zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@cecha_kondycja)df20 #</p>
                <h2>Test Kondycji</h2>
                <p>#KON}}{{@cecha_kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@cecha_budowa_ciala)df20 #</p>
                <h2>Test Budowy Ciała</h2>
                <p>#BC}}{{@cecha_budowa_ciala}}</p>
            </td>
        </tr>
        <tr>
            <th>Inteligencja</th>
            <th>Ogłada</th>
            <th>Moc</th>
            <th></th>
        </tr>
        <tr>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@cecha_inteligencja)df20 #</p>
                <h2>Test Inteligencji</h2>
                <p>#INT}}{{@cecha_inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@cecha_oglada)df20 #</p>
                <h2>Test Ogłady</h2>
                <p>#OGŁ}}{{@cecha_oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@cecha_moc)df20 #</p>
                <h2>Test Mocy</h2>
                <p>#MOC}}{{@cecha_moc}}</p>
            </td>
            <td></td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th>
                <p>Modyfikator <br>Obrażeń</p>
            </th>
            <th>
                <p>Maks <br>Życia</p>
            </th>
            <th>Ruch</th>
            <th>
                <p>Maks<br>Poczytalności</p>
            </th>
            <th>Maks Mocy</th>
        </tr>
        <tr>
            <td style="text-align:center">{{?}}</td>
            <td style="text-align:center">{{?}}</td>
            <td style="text-align:center">{{@po_ruch}}</td>
            <td style="text-align:center">{{@po_poczytalnosc}}</td>
            <td style="text-align:center">{{?}}</td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th></th>
            <th style="text-align:right">Pancerz</th>
            <th style="text-align:left"></th>
            <th></th>
        </tr>
        <tr>
            <th>Głowa</th>
            <th>Korpus</th>
            <th>Ręce</th>
            <th>Nogi</th>
        </tr>
        <tr>
            <td style="text-align:center">{{@pancerz_glowa}}</td>
            <td style="text-align:center">{{@pancerz_korpus}}</td>
            <td style="text-align:center">{{@pancerz_nogi}}</td>
            <td style="text-align:center">{{@pancerz_rece}}</td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th></th>
            <th></th>
            <th>Walka</th>
            <th></th>
            <th></th>
        </tr>
        <tr>
            <th>Unik</th>
            <th>Parowanie</th>
            <th>Pierwsza Pomoc</th>
            <th>Medycyna</th>
            <th>Chwyty</th>
        </tr>
        <tr>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_unik)df&gt;=floor(100-((100-@um_unik)/20)) #</p>
                <h2>Unik</h2>
                <p>#RZUĆ}}<br><strong>{{@um_unik}}</strong>{{floor(100-((100-@um_unik)/20))}}{{floor(@unik/5)}}{{floor(@um_unik/20)}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_parowanie)df&gt;=floor(100-((100-@um_parowanie)/20)) #</p>
                <h2>Parowanie</h2>
                <p>#RZUĆ}}<br><strong>{{@um_parowanie}}</strong>{{floor(100-((100-@um_parowanie)/20))}}{{floor(@um_parowanie/5)}}{{floor(@um_parowanie/20)}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_pierwsza_pomoc)df&gt;=floor(100-((100-@um_pierwsza_pomoc)/20)) #</p>
                <h2>Pierwsza Pomoc</h2>
                <p>#RZUĆ}}<br><strong>{{@um_pierwsza_pomoc}}</strong>{{floor(100-((100-@um_pierwsza_pomoc)/20))}}{{floor(@um_pierwsza_pomoc/5)}}{{floor(@um_pierwsza_pomoc/20)}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_medycyna)df&gt;=floor(100-((100-@um_medycyna)/20)) #</p>
                <h2>Medycyna</h2>
                <p>#RZUĆ}}<br><strong>{{@um_medycyna}}</strong>{{floor(100-((100-@um_medycyna)/20))}}{{floor(@um_medycyna/5)}}{{floor(@um_medycyna/20)}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_chwyty)df&gt;=floor(100-((100-@um_chwyty)/20)) #</p>
                <h2>Chwyty</h2>
                <p>#RZUĆ}}<br><strong>{{@um_chwyty}}</strong>{{floor(100-((100-@um_chwyty)/20))}}{{floor(@um_chwyty/5)}}{{floor(@um_chwyty/20)}}</p>
            </td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th>Bonusy</th>
            <th>Broń runiczna</th>
            <th>Wzm. Broń runiczna</th>
            <th>Tatuaże Runiczne</th>
            <th>Mięso Demonów</th>
        </tr>
        <tr>
            <th style="text-align:center">MO</th>
            <td style="text-align:center">{{@bon_br_mo}}</td>
            <td style="text-align:center">{{@bon_wbr_mo}}</td>
            <td style="text-align:center">{{@bon_tr_mo}}</td>
            <td style="text-align:center">{{@bon_m_mo}}</td>
        </tr>
        <tr>
            <th style="text-align:center">Regen.</th>
            <td style="text-align:center">1PŻ/Tura</td>
            <td style="text-align:center">1PŻ/Tura</td>
            <td style="text-align:center">1K3 PŻ/Tura</td>
            <td style="text-align:center">1K3+1 PŻ/Tura</td>
        </tr>
        <tr>
            <th style="text-align:center">SIŁ</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_br_sila)df20 #</p>
                <h2>Test Siły (Broń runiczna)</h2>
                <p>#SIŁ}}{{@bon_br_sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_wbr_sila)df20 #</p>
                <h2>Test Siły (Wzmocniona broń runiczna)</h2>
                <p>#SIŁ}}{{@bon_wbr_sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_tr_sila)df20 #</p>
                <h2>Test Siły (Tatuaże)</h2>
                <p>#SIŁ}}{{@bon_tr_sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_m_sila)df20 #</p>
                <h2>Test Siły (Mięso Demonów)</h2>
                <p>#SIŁ}}{{@bon_m_sila}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">KON</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_br_kondycja)df20 #</p>
                <h2>Test Kondycji (Broń runiczna)</h2>
                <p>#KON}}{{@bon_br_kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_wbr_kondycja)df20 #</p>
                <h2>Test Kondycji (Wzmocniona Broń runiczna)</h2>
                <p>#KON}}{{@bon_wbr_kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_tr_kondycja)df20 #</p>
                <h2>Test Kondycji (Tatuaże)</h2>
                <p>#KON}}{{@bon_tr_kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_m_kondycja)df20 #</p>
                <h2>Test Kondycji (Mięso Demonów)</h2>
                <p>#KON}}{{@bon_m_kondycja}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">ZR</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_br_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Broń runiczna)</h2>
                <p>#ZR}}{{@bon_br_zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_wbr_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Wzmocniona Broń runiczna)</h2>
                <p>#ZR}}{{@bon_wbr_zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_tr_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Tatuaże)</h2>
                <p>#ZR}}{{@bon_tr_zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_m_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Mięso Demonów)</h2>
                <p>#ZR}}{{@bon_m_zrecznosc}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">OGŁ</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_br_oglada)df20 #</p>
                <h2>Test Ogłady (Broń runiczna)</h2>
                <p>#OGŁ}}{{@bon_br_oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_wbr_oglada)df20 #</p>
                <h2>Test Ogłady (Wzmocniona Broń runiczna)</h2>
                <p>#OGŁ}}{{@bon_wbr_oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_tr_oglada)df20 #</p>
                <h2>Test Ogłady (Tatuaże)</h2>
                <p>#OGŁ}}{{@bon_tr_oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_m_oglada)df20 #</p>
                <h2>Test Ogłady (Mięso Demonów)</h2>
                <p>#OGŁ}}{{@bon_m_oglada}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">INT</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_br_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Broń runiczna)</h2>
                <p>#INT}}{{@bon_br_inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_wbr_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Wzmocniona Broń runiczna)</h2>
                <p>#INT}}{{@bon_wbr_inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_tr_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Tatuaże)</h2>
                <p>#INT}}{{@bon_tr_inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bon_m_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Mięso Demonów)</h2>
                <p>#INT}}{{@bon_m_inteligencja}}</p>
            </td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th></th>
            <th style="text-align:right">Umieję</th>
            <th style="text-align:left">tności</th>
            <th></th>
        </tr>
        <tr>
            <td style="text-align:center">Alfabetyzm</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_alfabetyzm)df&gt;=floor(100-((100-@um_alfabetyzm)/20)) #</p>
                <h2>Test Alfabetyzmu</h2>
                <p>#RZUĆ}}<strong>{{@um_alfabetyzm}}</strong>{{floor(100-((100-@um_alfabetyzm)/20))}}{{floor(@um_alfabetyzm/5)}}{{floor(@um_alfabetyzm/20)}}</p>
            </td>
            <td style="text-align:center">Bijatyka</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_bijatyka)df&gt;=floor(100-((100-@um_bijatyka)/20)) #</p>
                <h2>Test Bijatyki</h2>
                <p>#RZUĆ}}<strong>{{@um_bijatyka}}</strong>{{floor(100-((100-@um_bijatyka)/20))}}{{floor(@um_bijatyka/5)}}{{floor(@um_bijatyka/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Broń Biała Kolna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_bron_biala_kolna)df&gt;=floor(100-((100-@um_bron_biala_kolna)/20)) #</p>
                <h2>Test Broń Biała Kolna</h2>
                <p>#RZUĆ}}<strong>{{@um_bron_biala_kolna}}</strong>{{floor(100-((100-@um_bron_biala_kolna)/20))}}{{floor(@um_bron_biala_kolna/5)}}{{floor(@um_bron_biala_kolna/20)}}</p>
            </td>
            <td style="text-align:center">Broń Biała Obuchowa</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_bron_biala_obuchowa)df&gt;=floor(100-((100-@um_bron_biala_obuchowa)/20)) #</p>
                <h2>Test Broń Biała obuchowa</h2>
                <p>#RZUĆ}}<strong>{{@um_bron_biala_obuchowa}}</strong>{{floor(100-((100-@um_bron_biala_obuchowa)/20))}}{{floor(@um_bron_biala_obuchowa/5)}}{{floor(@um_bron_biala_obuchowa/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Broń Biała Sieczna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_bron_biala_sieczna)df&gt;=floor(100-((100-@um_bron_biala_sieczna)/20)) #</p>
                <h2>Test Broń Biała Sieczna</h2>
                <p>#RZUĆ}}<strong>{{@um_bron_biala_sieczna}}</strong>{{floor(100-((100-@um_bron_biala_sieczna)/20))}}{{floor(@um_bron_biala_sieczna/5)}}{{floor(@um_bron_biala_sieczna/20)}}</p>
            </td>
            <td style="text-align:center">Broń Dystansowa Miotająca</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_bron_dystansowa_miotajaca)df&gt;=floor(100-((100-@um_bron_dystansowa_miotajaca)/20)) #</p>
                <h2>Test Broń Dystansowa Miotająca</h2>
                <p>#RZUĆ}}<strong>{{@um_bron_dystansowa_miotajaca}}</strong>{{floor(100-((100-@um_bron_dystansowa_miotajaca)/20))}}{{floor(@um_bron_dystansowa_miotajaca/5)}}{{floor(@um_bron_dystansowa_miotajaca/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Broń Dystansowa Miotana</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_bron_dystansowa_miotana)df&gt;=floor(100-((100-@um_bron_dystansowa_miotana)/20)) #</p>
                <h2>Test Broń Dystansowa Miotana</h2>
                <p>#RZUĆ}}<strong>{{@um_bron_dystansowa_miotana}}</strong>{{floor(100-((100-@um_bron_dystansowa_miotana)/20))}}{{floor(@um_bron_dystansowa_miotana/5)}}{{floor(@um_bron_dystansowa_miotana/20)}}</p>
            </td>
            <td style="text-align:center">Broń Dystansowa Palna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_bron_dystansowa_palna)df&gt;=floor(100-((100-@um_bron_dystansowa_palna)/20)) #</p>
                <h2>Test Broń Dystansowa Palna</h2>
                <p>#RZUĆ}}<strong>{{@um_bron_dystansowa_palna}}</strong>{{floor(100-((100-@um_bron_dystansowa_palna)/20))}}{{floor(@um_bron_dystansowa_palna/5)}}{{floor(@um_bron_dystansowa_palna/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Charakteryzacja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_charakteryzacja)df&gt;=floor(100-((100-@um_charakteryzacja)/20)) #</p>
                <h2>Charakteryzacja</h2>
                <p>#RZUĆ}}<strong>{{@um_charakteryzacja}}</strong>{{floor(100-((100-@um_charakteryzacja)/20))}}{{floor(@um_charakteryzacja/5)}}{{floor(@um_charakteryzacja/20)}}</p>
            </td>
            <td style="text-align:center">Chwyty</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_chwyty)df&gt;=floor(100-((100-@um_chwyty)/20)) #</p>
                <h2>Chwyty</h2>
                <p>#RZUĆ}}<strong>{{@um_chwyty}}</strong>{{floor(100-((100-@um_chwyty)/20))}}{{floor(@um_chwyty/5)}}{{floor(@um_chwyty/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Dematerializacja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_dematerializacja)df&gt;=floor(100-((100-@um_dematerializacja)/20)) #</p>
                <h2>Dematerializacja</h2>
                <p>#RZUĆ}}<strong>{{@um_dematerializacja}}</strong>{{floor(100-((100-@um_dematerializacja)/20))}}{{floor(@um_dematerializacja/5)}}{{floor(@um_dematerializacja/20)}}</p>
            </td>
            <td style="text-align:center">Dowodzenie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_dowodzenie)df&gt;=floor(100-((100-@um_dowodzenie)/20)) #</p>
                <h2>Dowodzenie</h2>
                <p>#RZUĆ}}<strong>{{@um_dowodzenie}}</strong>{{floor(100-((100-@um_dowodzenie)/20))}}{{floor(@um_dowodzenie/5)}}{{floor(@um_dowodzenie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Etykieta 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_etykieta_1)df&gt;=floor(100-((100-@um_etykieta_1)/20)) #</p>
                <h2>Etykieta 1</h2>
                <p>#RZUĆ}}<strong>{{@um_etykieta_1}}</strong>{{floor(100-((100-@um_etykieta_1)/20))}}{{floor(@um_etykieta_1/5)}}{{floor(@um_etykieta_1/20)}}</p>
            </td>
            <td style="text-align:center">Etykieta 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_etykieta_2)df&gt;=floor(100-((100-@um_etykieta_2)/20)) #</p>
                <h2>Etykieta 2</h2>
                <p>#RZUĆ}}<strong>{{@um_etykieta_2}}</strong>{{floor(100-((100-@um_etykieta_2)/20))}}{{floor(@um_etykieta_2/5)}}{{floor(@um_etykieta_2/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Etykieta 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_etykieta_3)df&gt;=floor(100-((100-@um_etykieta_3)/20)) #</p>
                <h2>Etykieta 3</h2>
                <p>#RZUĆ}}<strong>{{@um_etykieta_3}}</strong>{{floor(100-((100-@um_etykieta_3)/20))}}{{floor(@um_etykieta_3/5)}}{{floor(@um_etykieta_3/20)}}</p>
            </td>
            <td style="text-align:center">Gadanina</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_gadanina)df&gt;=floor(100-((100-@um_gadanina)/20)) #</p>
                <h2>Gadanina</h2>
                <p>#RZUĆ}}<strong>{{@um_gadanina}}</strong>{{floor(100-((100-@um_gadanina)/20))}}{{floor(@um_gadanina/5)}}{{floor(@um_gadanina/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Hazard</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_hazard)df&gt;=floor(100-((100-@um_hazard)/20)) #</p>
                <h2>Hazard</h2>
                <p>#RZUĆ}}<strong>{{@um_hazard}}</strong>{{floor(100-((100-@um_hazard)/20))}}{{floor(@um_hazard/5)}}{{floor(@um_hazard/20)}}</p>
            </td>
            <td style="text-align:center">Hipnoza</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_hipnoza)df&gt;=floor(100-((100-@um_hipnoza)/20)) #</p>
                <h2>Hipnoza</h2>
                <p>#RZUĆ}}<strong>{{@um_hipnoza}}</strong>{{floor(100-((100-@um_hipnoza)/20))}}{{floor(@um_hipnoza/5)}}{{floor(@um_hipnoza/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Jeździectwo</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_jezdziectwo)df&gt;=floor(100-((100-@um_jezdziectwo)/20)) #</p>
                <h2>Jeździectwo</h2>
                <p>#RZUĆ}}<strong>{{@um_jezdziectwo}}</strong>{{floor(100-((100-@um_jezdziectwo)/20))}}{{floor(@um_jezdziectwo/5)}}{{floor(@um_jezdziectwo/20)}}</p>
            </td>
            <td style="text-align:center">Język Ojczysty</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_jezyk_ojczysty)df&gt;=floor(100-((100-@um_jezyk_ojczysty)/20)) #</p>
                <h2>Język Ojczysty</h2>
                <p>#RZUĆ}}<strong>{{@um_jezyk_ojczysty}}</strong>{{floor(100-((100-@um_jezyk_ojczysty)/20))}}{{floor(@um_jezyk_ojczysty/5)}}{{floor(@um_jezyk_ojczysty/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Język 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_jezyk_2)df&gt;=floor(100-((100-@um_jezyk_2)/20)) #</p>
                <h2>Język 2</h2>
                <p>#RZUĆ}}<strong>{{@um_jezyk_2}}</strong>{{floor(100-((100-@um_jezyk_2)/20))}}{{floor(@um_jezyk_2/5)}}{{floor(@um_jezyk_2/20)}}</p>
            </td>
            <td style="text-align:center">Kuglarstwo</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_kuglarstwo)df&gt;=floor(100-((100-@um_kuglarstwo)/20)) #</p>
                <h2>Kuglarstwo</h2>
                <p>#RZUĆ}}<strong>{{@um_kuglarstwo}}</strong>{{floor(100-((100-@um_kuglarstwo)/20))}}{{floor(@um_kuglarstwo/5)}}{{floor(@um_kuglarstwo/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Medycyna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_medycyna)df&gt;=floor(100-((100-@um_medycyna)/20)) #</p>
                <h2>Medycyna</h2>
                <p>#RZUĆ}}<strong>{{@um_medycyna}}</strong>{{floor(100-((100-@um_medycyna)/20))}}{{floor(@um_medycyna/5)}}{{floor(@um_medycyna/20)}}</p>
            </td>
            <td style="text-align:center">Nasłuchiwanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_nasluchiwanie)df&gt;=floor(100-((100-@um_nasluchiwanie)/20)) #</p>
                <h2>Nasłuchiwanie</h2>
                <p>#RZUĆ}}<strong>{{@um_nasluchiwanie}}</strong>{{floor(100-((100-@um_nasluchiwanie)/20))}}{{floor(@um_nasluchiwanie/5)}}{{floor(@um_nasluchiwanie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Nauczanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_nauczanie)df&gt;=floor(100-((100-@um_nauczanie)/20)) #</p>
                <h2>Nauczanie</h2>
                <p>#RZUĆ}}<strong>{{@um_nauczanie}}</strong>{{floor(100-((100-@um_nauczanie)/20))}}{{floor(@um_nauczanie/5)}}{{floor(@um_nauczanie/20)}}</p>
            </td>
            <td style="text-align:center">Nauka 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_nauka_1)df&gt;=floor(100-((100-@um_nauka_1)/20)) #</p>
                <h2>Nauka 1</h2>
                <p>#RZUĆ}}<strong>{{@um_nauka_1}}</strong>{{floor(100-((100-@um_nauka_1)/20))}}{{floor(@um_nauka_1/5)}}{{floor(@um_nauka_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Nauka 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_nauka_2)df&gt;=floor(100-((100-@um_nauka_2)/20)) #</p>
                <h2>Nauka 2</h2>
                <p>#RZUĆ}}<strong>{{@um_nauka_2}}</strong>{{floor(100-((100-@um_nauka_2)/20))}}{{floor(@um_nauka_2/5)}}{{floor(@um_nauka_2/20)}}</p>
            </td>
            <td style="text-align:center">Nauka 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_nauka_3)df&gt;=floor(100-((100-@um_nauka_3)/20)) #</p>
                <h2>Nauka 3</h2>
                <p>#RZUĆ}}<strong>{{@um_nauka_3}}</strong>{{floor(100-((100-@um_nauka_3)/20))}}{{floor(@um_nauka_3/5)}}{{floor(@um_nauka_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Nawigacja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_nawigacja)df&gt;=floor(100-((100-@um_nawigacja)/20)) #</p>
                <h2>Nawigacja</h2>
                <p>#RZUĆ}}<strong>{{@um_nawigacja}}</strong>{{floor(100-((100-@um_nawigacja)/20))}}{{floor(@um_nawigacja/5)}}{{floor(@um_nawigacja/20)}}</p>
            </td>
            <td style="text-align:center">Negocjacje</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_negocjacje)df&gt;=floor(100-((100-@um_negocjacje)/20)) #</p>
                <h2>Negocjacje</h2>
                <p>#RZUĆ}}<strong>{{@um_negocjacje}}</strong>{{floor(100-((100-@um_negocjacje)/20))}}{{floor(@um_negocjacje/5)}}{{floor(@um_negocjacje/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Obsługa Altyrelii</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_obsluga_altyrelii)df&gt;=floor(100-((100-@um_obsluga_altyrelii)/20)) #</p>
                <h2>Obsługa Altyrelii</h2>
                <p>#RZUĆ}}<strong>{{@um_obsluga_altyrelii}}</strong>{{floor(100-((100-@um_obsluga_altyrelii)/20))}}{{floor(@um_obsluga_altyrelii/5)}}{{floor(@um_obsluga_altyrelii/20)}}</p>
            </td>
            <td style="text-align:center">Parowanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_parowanie)df&gt;=floor(100-((100-@um_parowanie)/20)) #</p>
                <h2>Parowanie</h2>
                <p>#RZUĆ}}<strong>{{@um_parowanie}}</strong>{{floor(100-((100-@um_parowanie)/20))}}{{floor(@um_parowanie/5)}}{{floor(@um_parowanie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Persfazja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_persfazja)df&gt;=floor(100-((100-@um_persfazja)/20)) #</p>
                <h2>Persfazja</h2>
                <p>#RZUĆ}}<strong>{{@um_persfazja}}</strong>{{floor(100-((100-@um_persfazja)/20))}}{{floor(@um_persfazja/5)}}{{floor(@um_persfazja/20)}}</p>
            </td>
            <td style="text-align:center">Pierwsza Pomoc</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_pierwsza_pomoc)df&gt;=floor(100-((100-@um_pierwsza_pomoc)/20)) #</p>
                <h2>Pierwsza Pomoc</h2>
                <p>#RZUĆ}}<strong>{{@um_pierwsza_pomoc}}</strong>{{floor(100-((100-@um_pierwsza_pomoc)/20))}}{{floor(@um_pierwsza_pomoc/5)}}{{floor(@um_pierwsza_pomoc/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Pływanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_plywanie)df&gt;=floor(100-((100-@um_plywanie)/20)) #</p>
                <h2>Pływanie</h2>
                <p>#RZUĆ}}<strong>{{@um_plywanie}}</strong>{{floor(100-((100-@um_plywanie)/20))}}{{floor(@um_plywanie/5)}}{{floor(@um_plywanie/20)}}</p>
            </td>
            <td style="text-align:center">Powożenie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_powozenie)df&gt;=floor(100-((100-@um_powozenie)/20)) #</p>
                <h2>Powożenie</h2>
                <p>#RZUĆ}}<strong>{{@um_powozenie}}</strong>{{floor(100-((100-@um_powozenie)/20))}}{{floor(@um_powozenie/5)}}{{floor(@um_powozenie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Reaserch</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_reaserch)df&gt;=floor(100-((100-@um_reaserch)/20)) #</p>
                <h2>Reaserch</h2>
                <p>#RZUĆ}}<strong>{{@um_reaserch}}</strong>{{floor(100-((100-@um_reaserch)/20))}}{{floor(@um_reaserch/5)}}{{floor(@um_reaserch/20)}}</p>
            </td>
            <td style="text-align:center">Rzemiosło 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_rzemioslo_1)df&gt;=floor(100-((100-@um_rzemioslo_1)/20)) #</p>
                <h2>Rzemiosło 1</h2>
                <p>#RZUĆ}}<strong>{{@um_rzemioslo_1}}</strong>{{floor(100-((100-@um_rzemioslo_1)/20))}}{{floor(@um_rzemioslo_1/5)}}{{floor(@um_rzemioslo_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Rzemiosło 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_rzemioslo_2)df&gt;=floor(100-((100-@um_rzemioslo_2)/20)) #</p>
                <h2>Rzemiosło 2</h2>
                <p>#RZUĆ}}<strong>{{@um_rzemioslo_2}}</strong>{{floor(100-((100-@um_rzemioslo_2)/20))}}{{floor(@um_rzemioslo_2/5)}}{{floor(@um_rzemioslo_2/20)}}</p>
            </td>
            <td style="text-align:center">Rzemiosło 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_rzemioslo_3)df&gt;=floor(100-((100-@um_rzemioslo_3)/20)) #</p>
                <h2>Rzemiosło 3</h2>
                <p>#RZUĆ}}<strong>{{@um_rzemioslo_3}}</strong>{{floor(100-((100-@um_rzemioslo_3)/20))}}{{floor(@um_rzemioslo_3/5)}}{{floor(@um_rzemioslo_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Rzucanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_rzucanie)df&gt;=floor(100-((100-@um_rzucanie)/20)) #</p>
                <h2>Rzucanie</h2>
                <p>#RZUĆ}}<strong>{{@um_rzucanie}}</strong>{{floor(100-((100-@um_rzucanie)/20))}}{{floor(@um_rzucanie/5)}}{{floor(@um_rzucanie/20)}}</p>
            </td>
            <td style="text-align:center">Skok</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_skok)df&gt;=floor(100-((100-@um_skok)/20)) #</p>
                <h2>Skok</h2>
                <p>#RZUĆ}}<strong>{{@um_skok}}</strong>{{floor(100-((100-@um_skok)/20))}}{{floor(@um_skok/5)}}{{floor(@um_skok/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Skradanie się</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_skradanie_sie)df&gt;=floor(100-((100-@um_skradanie_sie)/20)) #</p>
                <h2>Skradanie się</h2>
                <p>#RZUĆ}}<strong>{{@um_skradanie_sie}}</strong>{{floor(100-((100-@um_skradanie_sie)/20))}}{{floor(@um_skradanie_sie/5)}}{{floor(@um_skradanie_sie/20)}}</p>
            </td>
            <td style="text-align:center">Spostrzegawczość</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_spostrzegawczosc)df&gt;=floor(100-((100-@um_spostrzegawczosc)/20)) #</p>
                <h2>Spostrzegawczość</h2>
                <p>#RZUĆ}}<strong>{{@um_spostrzegawczosc}}</strong>{{floor(100-((100-@um_spostrzegawczosc)/20))}}{{floor(@um_spostrzegawczosc/5)}}{{floor(@um_spostrzegawczosc/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Status</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_status)df&gt;=floor(100-((100-@um_status)/20)) #</p>
                <h2>Status</h2>
                <p>#RZUĆ}}<strong>{{@um_status}}</strong>{{floor(100-((100-@um_status)/20))}}{{floor(@um_status/5)}}{{floor(@um_status/20)}}</p>
            </td>
            <td style="text-align:center">Stawianie Run</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_stawianie_run)df&gt;=floor(100-((100-@um_stawianie_run)/20)) #</p>
                <h2>Stawianie Run</h2>
                <p>#RZUĆ}}<strong>{{@um_stawianie_run}}</strong>{{floor(100-((100-@um_stawianie_run)/20))}}{{floor(@um_stawianie_run/5)}}{{floor(@um_stawianie_run/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Strategia</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_strategia)df&gt;=floor(100-((100-@um_strategia)/20)) #</p>
                <h2>Strategia</h2>
                <p>#RZUĆ}}<strong>{{@um_strategia}}</strong>{{floor(100-((100-@um_strategia)/20))}}{{floor(@um_strategia/5)}}{{floor(@um_strategia/20)}}</p>
            </td>
            <td style="text-align:center">Sztuka 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuka_1)df&gt;=floor(100-((100-@um_sztuka_1)/20)) #</p>
                <h2>Sztuka 1</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuka_1}}</strong>{{floor(100-((100-@um_sztuka_1)/20))}}{{floor(@um_sztuka_1/5)}}{{floor(@um_sztuka_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Sztuka 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuka_2)df&gt;=floor(100-((100-@um_sztuka_2)/20)) #</p>
                <h2>Sztuka 2</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuka_2}}</strong>{{floor(100-((100-@um_sztuka_2)/20))}}{{floor(@um_sztuka_2/5)}}{{floor(@um_sztuka_2/20)}}</p>
            </td>
            <td style="text-align:center">Sztuka 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuka_3)df&gt;=floor(100-((100-@um_sztuka_3)/20)) #</p>
                <h2>Sztuka 3</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuka_3}}</strong>{{floor(100-((100-@um_sztuka_3)/20))}}{{floor(@um_sztuka_3/5)}}{{floor(@um_sztuka_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Sztuka Przetrwania 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuka_przetrwania_1)df&gt;=floor(100-((100-@um_sztuka_przetrwania_1)/20)) #</p>
                <h2>Sztuka Przetrwania</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuka_przetrwania_1}}</strong>{{floor(100-((100-@um_sztuka_przetrwania_1)/20))}}{{floor(@um_sztuka_przetrwania_1/5)}}{{floor(@um_sztuka_przetrwania_1/20)}}</p>
            </td>
            <td style="text-align:center">Sztuka Przetrwania 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuka_przetrwania_2)df&gt;=floor(100-((100-@um_sztuka_przetrwania_2)/20)) #</p>
                <h2>Sztuka Przetrwania</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuka_przetrwania_2}}</strong>{{floor(100-((100-@um_sztuka_przetrwania_2)/20))}}{{floor(@um_sztuka_przetrwania_2/5)}}{{floor(@um_sztuka_przetrwania_2/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Sztuka Przetrwania 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuka_przetrwania_3)df&gt;=floor(100-((100-@um_sztuka_przetrwania_3)/20)) #</p>
                <h2>Sztuka Przetrwania</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuka_przetrwania_3}}</strong>{{floor(100-((100-@um_sztuka_przetrwania_3)/20))}}{{floor(@um_sztuka_przetrwania_3/5)}}{{floor(@um_sztuka_przetrwania_3/20)}}</p>
            </td>
            <td style="text-align:center">Sztuki Walki 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuki_walki_1)df&gt;=floor(100-((100-@um_sztuki_walki_1)/20)) #</p>
                <h2>Sztuki Walki</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuki_walki_1}}</strong>{{floor(100-((100-@um_sztuki_walki_1)/20))}}{{floor(@um_sztuki_walki_1/5)}}{{floor(@um_sztuki_walki_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Sztuki Walki 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuki_walki_2)df&gt;=floor(100-((100-@um_sztuki_walki_2)/20)) #</p>
                <h2>Sztuki Walki</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuki_walki_2}}</strong>{{floor(100-((100-@um_sztuki_walki_2)/20))}}{{floor(@um_sztuki_walki_2/5)}}{{floor(@um_sztuki_walki_2/20)}}</p>
            </td>
            <td style="text-align:center">Sztuki Walki 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_sztuki_walki_3)df&gt;=floor(100-((100-@um_sztuki_walki_3)/20)) #</p>
                <h2>Sztuki Walki</h2>
                <p>#RZUĆ}}<strong>{{@um_sztuki_walki_3}}</strong>{{floor(100-((100-@um_sztuki_walki_3)/20))}}{{floor(@um_sztuki_walki_3/5)}}{{floor(@um_sztuki_walki_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Tropienie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_tropienie)df&gt;=floor(100-((100-@um_tropienie)/20)) #</p>
                <h2>Tropienie</h2>
                <p>#RZUĆ}}<strong>{{@um_tropienie}}</strong>{{floor(100-((100-@um_tropienie)/20))}}{{floor(@um_tropienie/5)}}{{floor(@um_tropienie/20)}}</p>
            </td>
            <td style="text-align:center">Ukrywanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_ukrywanie)df&gt;=floor(100-((100-@um_ukrywanie)/20)) #</p>
                <h2>Ukrywanie</h2>
                <p>#RZUĆ}}<strong>{{@um_ukrywanie}}</strong>{{floor(100-((100-@um_ukrywanie)/20))}}{{floor(@um_ukrywanie/5)}}{{floor(@um_ukrywanie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Unik</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_unik)df&gt;=floor(100-((100-@um_unik)/20)) #</p>
                <h2>Unik</h2>
                <p>#RZUĆ}}<strong>{{@um_unik}}</strong>{{floor(100-((100-@um_unik)/20))}}{{floor(@um_unik/5)}}{{floor(@um_unik/20)}}</p>
            </td>
            <td style="text-align:center">Walka Tarczą</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_walka_tarcza)df&gt;=floor(100-((100-@um_walka_tarcza)/20)) #</p>
                <h2>Walka Tarczą</h2>
                <p>#RZUĆ}}<strong>{{@um_walka_tarcza}}</strong>{{floor(100-((100-@um_walka_tarcza)/20))}}{{floor(@um_walka_tarcza/5)}}{{floor(@um_walka_tarcza/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wiedza 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wiedza_1)df&gt;=floor(100-((100-@um_wiedza_1)/20)) #</p>
                <h2>Wiedza 1</h2>
                <p>#RZUĆ}}<strong>{{@um_wiedza_1}}</strong>{{floor(100-((100-@um_wiedza_1)/20))}}{{floor(@um_wiedza_1/5)}}{{floor(@um_wiedza_1/20)}}</p>
            </td>
            <td style="text-align:center">Wiedza 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wiedza_2)df&gt;=floor(100-((100-@um_wiedza_2)/20)) #</p>
                <h2>Wiedza 2</h2>
                <p>#RZUĆ}}<strong>{{@um_wiedza_2}}</strong>{{floor(100-((100-@um_wiedza_2)/20))}}{{floor(@um_wiedza_2/5)}}{{floor(@um_wiedza_2/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wiedza 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wiedza_3)df&gt;=floor(100-((100-@um_wiedza_3)/20)) #</p>
                <h2>Wiedza 3</h2>
                <p>#RZUĆ}}<strong>{{@um_wiedza_3}}</strong>{{floor(100-((100-@um_wiedza_3)/20))}}{{floor(@um_wiedza_3/5)}}{{floor(@um_wiedza_3/20)}}</p>
            </td>
            <td style="text-align:center">Wnikliwość</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wnikliwosc)df&gt;=floor(100-((100-@um_wnikliwosc)/20)) #</p>
                <h2>Wnikliwość</h2>
                <p>#RZUĆ}}<strong>{{@um_wnikliwosc}}</strong>{{floor(100-((100-@um_wnikliwosc)/20))}}{{floor(@um_wnikliwosc/5)}}{{floor(@um_wnikliwosc/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wróżenie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wrozenie)df&gt;=floor(100-((100-@um_wrozenie)/20)) #</p>
                <h2>Wróżenie</h2>
                <p>#RZUĆ}}<strong>{{@um_wrozenie}}</strong>{{floor(100-((100-@um_wrozenie)/20))}}{{floor(@um_wrozenie/5)}}{{floor(@um_wrozenie/20)}}</p>
            </td>
            <td style="text-align:center">Wspinaczka</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wspinaczka)df&gt;=floor(100-((100-@um_wspinaczka)/20)) #</p>
                <h2>Wspinaczka</h2>
                <p>#RZUĆ}}<strong>{{@um_wspinaczka}}</strong>{{floor(100-((100-@um_wspinaczka)/20))}}{{floor(@um_wspinaczka/5)}}{{floor(@um_wspinaczka/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wycena</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wycena)df&gt;=floor(100-((100-@um_wycena)/20)) #</p>
                <h2>Wycena</h2>
                <p>#RZUĆ}}<strong>{{@um_wycena}}</strong>{{floor(100-((100-@um_wycena)/20))}}{{floor(@um_wycena/5)}}{{floor(@um_wycena/20)}}</p>
            </td>
            <td style="text-align:center">Występy Publiczne 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wystepy_publiczne_1)df&gt;=floor(100-((100-@um_wystepy_publiczne_1)/20)) #</p>
                <h2>Występy Publiczne 1</h2>
                <p>#RZUĆ}}<strong>{{@um_wystepy_publiczne_1}}</strong>{{floor(100-((100-@um_wystepy_publiczne_1)/20))}}{{floor(@um_wystepy_publiczne_1/5)}}{{floor(@um_wystepy_publiczne_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Występy Publiczne 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wystepy_publiczne_2)df&gt;=floor(100-((100-@um_wystepy_publiczne_2)/20)) #</p>
                <h2>Występy Publiczne 2</h2>
                <p>#RZUĆ}}<strong>{{@um_wystepy_publiczne_2}}</strong>{{floor(100-((100-@um_wystepy_publiczne_2)/20))}}{{floor(@um_wystepy_publiczne_2/5)}}{{floor(@um_wystepy_publiczne_2/20)}}</p>
            </td>
            <td style="text-align:center">Występy Publiczne 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_wystepy_publiczne_3)df&gt;=floor(100-((100-@um_wystepy_publiczne_3)/20)) #</p>
                <h2>Występy Publiczne 3</h2>
                <p>#RZUĆ}}<strong>{{@um_wystepy_publiczne_3}}</strong>{{floor(100-((100-@um_wystepy_publiczne_3)/20))}}{{floor(@um_wystepy_publiczne_3/5)}}{{floor(@um_wystepy_publiczne_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Zmysły</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_zmysly)df&gt;=floor(100-((100-@um_zmysly)/20)) #</p>
                <h2>Zmysły</h2>
                <p>#RZUĆ}}<strong>{{@um_zmysly}}</strong>{{floor(100-((100-@um_zmysly)/20))}}{{floor(@um_zmysly/5)}}{{floor(@um_zmysly/20)}}</p>
            </td>
            <td style="text-align:center">Zręczne Palce</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@um_zreczne_palce)df&gt;=floor(100-((100-@um_zreczne_palce)/20)) #</p>
                <h2>Zręczne Palce</h2>
                <p>#RZUĆ}}<strong>{{@um_zreczne_palce}}</strong>{{floor(100-((100-@um_zreczne_palce)/20))}}{{floor(@um_zreczne_palce/5)}}{{floor(@um_zreczne_palce/20)}}</p>
            </td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th style="text-align:center">Wygląd</th>
        </tr>
        <tr>
            <td style="text-align:left">?</td>
        </tr>
        <tr>
            <th style="text-align:center">Charakter</th>
        </tr>
        <tr>
            <td style="text-align:left">?</td>
        </tr>
        <tr>
            <th style="text-align:center">Backstory</th>
        </tr>
        <tr>
            <td style="text-align:left">?</td>
        </tr>
    </tbody>
</table>
