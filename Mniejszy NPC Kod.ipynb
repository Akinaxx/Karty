# %%
<table>
    <tbody>
        <tr>
            <th style="text-align:right;width:20%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Imię i nazwisko:</span></span></th>
            <td style="text-align:center;width:25%">
                <p style="line-height: 50%">Imie</p>
                <p style="line-height: 50%">Nazwisko</p>
            </td>
            <th style="text-align:right;width:10%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Wiek</span></span>:</th>
            <td style="text-align:center;width:10%">?</td>
            <th style="text-align:right;width:15%"><span style="text-decoration:underline"><span style="text-decoration: underline;">Profesja</span></span>:</th>
            <td style="text-align:center;width:20%">?</td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th style="text-align:left;width:20%">Krótki opis &nbsp</th>
            <td style="text-align:left;width:80%">?</td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th>
                <p>Modyfikator <br>Obrażeń</p>
            </th>
            <th>
                <p>Punkty Życia</p>
            </th>
            <th>Ruch</th>
            <th>Punkty Mocy</th>
        </tr>
        <tr>
            <td style="text-align:center">{{?}}</td>
            <td style="text-align:center">{{@punkty_zycia}}/{{@maks_punkty_zycia}}</td>
            <td style="text-align:center">{{@ruch}}</td>
            <td style="text-align:center">{{@punkty_mocy}}/{{@maks_punkty_mocy}}</td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th></th>
            <th style="text-align:right">Cechy_</th>
            <th style="text-align:left">Bohatera</th>
            <th></th>
        </tr>
        <tr>
            <th>Siła</th>
            <th>Zręczność</th>
            <th>Kondycja</th>
            <th>Budowa Ciała</th>
        </tr>
        <tr>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@sila)df20 #</p>
                <h2>Test Siły</h2>
                <p>#SIŁ}}{{@sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@zrecznosc)df20 #</p>
                <h2>Test Zręczności</h2>
                <p>#ZR}}{{@zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@kondycja)df20 #</p>
                <h2>Test Kondycji</h2>
                <p>#KON}}{{@kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@budowa_ciala)df20 #</p>
                <h2>Test Budowy Ciała</h2>
                <p>#BC}}{{@budowa_ciala}}</p>
            </td>
        </tr>
        <tr>
            <th>Inteligencja</th>
            <th>Ogłada</th>
            <th>Moc</th>
            <th></th>
        </tr>
        <tr>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@inteligencja)df20 #</p>
                <h2>Test Inteligencji</h2>
                <p>#INT}}{{@inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@oglada)df20 #</p>
                <h2>Test Ogłady</h2>
                <p>#OGŁ}}{{@oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@moc)df20cs1 #</p>
                <h2>Test Mocy</h2>
                <p>#MOC}}{{@moc}}</p>
            </td>
            <td></td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th></th>
            <th style="text-align:right">Pancerz</th>
            <th style="text-align:left"></th>
            <th></th>
        </tr>
        <tr>
            <th>Głowa</th>
            <th>Korpus</th>
            <th>Ręce</th>
            <th>Nogi</th>
        </tr>
        <tr>
            <td style="text-align:center">{{@pancerz_glowa}}</td>
            <td style="text-align:center">{{@pancerz_korpus}}</td>
            <td style="text-align:center">{{@pancerz_nogi}}</td>
            <td style="text-align:center">{{@pancerz_rece}}</td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th></th>
            <th style="text-align:right">Umieję</th>
            <th style="text-align:left">tności</th>
            <th></th>
        </tr>
        <tr>
            <td style="text-align:center">Alfabetyzm</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@alfabetyzm)df&gt;floor(100-((100-@alfabetyzm)/20)) #</p>
                <h2>Test Alfabetyzmu</h2>
                <p>#RZUĆ}}<strong>{{@alfabetyzm}}</strong>{{floor(100-((100-@alfabetyzm)/20))}}{{floor(@alfabetyzm/5)}}{{floor(@alfabetyzm/20)}}</p>
            </td>
            <td style="text-align:center">Bijatyka</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@bijatyka)df&gt;floor(100-((100-@bijatyka)/20)) #</p>
                <h2>Test Bijatyki</h2>
                <p>#RZUĆ}}<strong>{{@bijatyka}}</strong>{{floor(100-((100-@bijatyka)/20))}}{{floor(@bijatyka/5)}}{{floor(@bijatyka/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Broń Biała Kolna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@bron_biala_kolna)df&gt;floor(100-((100-@bron_biala_kolna)/20)) #</p>
                <h2>Test Broń Biała Kolna</h2>
                <p>#RZUĆ}}<strong>{{@bron_biala_kolna}}</strong>{{floor(100-((100-@@bron_biala_kolna)/20))}}{{floor(@bron_biala_kolna/5)}}{{floor(@bron_biala_kolna/20)}}</p>
            </td>
            <td style="text-align:center">Broń Biała Obuchowa</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@bron_biala_obuchowa)df&gt;floor(100-((100-@bron_biala_obuchowa)/20)) #</p>
                <h2>Test Broń Biała obuchowa</h2>
                <p>#RZUĆ}}<strong>{{@bron_biala_obuchowa}}</strong>{{floor(100-((100-@bron_biala_obuchowa)/20))}}{{floor(@bron_biala_obuchowa/5)}}{{floor(@bron_biala_obuchowa/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Broń Biała Sieczna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@bron_biala_sieczna)df&gt;floor(100-((100-@bron_biala_sieczna)/20)) #</p>
                <h2>Test Broń Biała Sieczna</h2>
                <p>#RZUĆ}}<strong>{{@bron_biala_sieczna}}</strong>{{floor(100-((100-@@bron_biala_sieczna)/20))}}{{floor(@bron_biala_sieczna/5)}}{{floor(@bron_biala_sieczna/20)}}</p>
            </td>
            <td style="text-align:center">Broń Dystansowa Miotająca</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@bron_dystansowa_miotajaca)df&gt;floor(100-((100-@bron_dystansowa_miotajaca)/20)) #</p>
                <h2>Test Broń Dystansowa Miotająca</h2>
                <p>#RZUĆ}}<strong>{{@bron_dystansowa_miotajaca}}</strong>{{floor(100-((100-@bron_dystansowa_miotajaca)/20))}}{{floor(@bron_dystansowa_miotajaca/5)}}{{floor(@bron_dystansowa_miotajaca/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Broń Dystansowa Miotana</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@bron_dystansowa_miotana)df&gt;floor(100-((100-@bron_dystansowa_miotana)/20)) #</p>
                <h2>Test Broń Dystansowa Miotana</h2>
                <p>#RZUĆ}}<strong>{{@bron_dystansowa_miotana}}</strong>{{floor(100-((100-@bron_dystansowa_miotana)/20))}}{{floor(@bron_dystansowa_miotana/5)}}{{floor(@bron_dystansowa_miotana/20)}}</p>
            </td>
            <td style="text-align:center">Broń Dystansowa Palna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@bron_dystansowa_palna)df&gt;floor(100-((100-@bron_dystansowa_palna)/20)) #</p>
                <h2>Test Broń Dystansowa Palna</h2>
                <p>#RZUĆ}}<strong>{{@bron_dystansowa_palna}}</strong>{{floor(100-((100-@bron_dystansowa_palna)/20))}}{{floor(@bron_dystansowa_palna/5)}}{{floor(@bron_dystansowa_palna/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Charakteryzacja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@charakteryzacja)df&gt;floor(100-((100-@charakteryzacja)/20)) #</p>
                <h2>Charakteryzacja</h2>
                <p>#RZUĆ}}<strong>{{@charakteryzacja}}</strong>{{floor(100-((100-@charakteryzacja)/20))}}{{floor(@charakteryzacja/5)}}{{floor(@charakteryzacja/20)}}</p>
            </td>
            <td style="text-align:center">Chwyty</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@chwyty)df&gt;floor(100-((100-@chwyty)/20)) #</p>
                <h2>Chwyty</h2>
                <p>#RZUĆ}}<strong>{{@chwyty}}</strong>{{floor(100-((100-@chwyty)/20))}}{{floor(@chwyty/5)}}{{floor(@chwyty/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Dematerializacja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@dematerializacja)df&gt;floor(100-((100-@dematerializacja)/20)) #</p>
                <h2>Dematerializacja</h2>
                <p>#RZUĆ}}<strong>{{@dematerializacja}}</strong>{{floor(100-((100-@dematerializacja)/20))}}{{floor(@dematerializacja/5)}}{{floor(@dematerializacja/20)}}</p>
            </td>
            <td style="text-align:center">Dowodzenie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@dowodzenie)df&gt;floor(100-((100-@dowodzenie)/20)) #</p>
                <h2>Dowodzenie</h2>
                <p>#RZUĆ}}<strong>{{@dowodzenie}}</strong>{{floor(100-((100-@dowodzenie)/20))}}{{floor(@dowodzenie/5)}}{{floor(@dowodzenie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Etykieta 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@etykieta_1)df&gt;floor(100-((100-@etykieta_1)/20)) #</p>
                <h2>Etykieta 1</h2>
                <p>#RZUĆ}}<strong>{{@etykieta_1}}</strong>{{floor(100-((100-@etykieta_1)/20))}}{{floor(@etykieta_1/5)}}{{floor(@etykieta_1/20)}}</p>
            </td>
            <td style="text-align:center">Etykieta 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@etykieta_2)df&gt;floor(100-((100-@etykieta_2)/20)) #</p>
                <h2>Etykieta 2</h2>
                <p>#RZUĆ}}<strong>{{@etykieta_2}}</strong>{{floor(100-((100-@etykieta_2)/20))}}{{floor(@etykieta_2/5)}}{{floor(@etykieta_2/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Etykieta 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@etykieta_3)df&gt;floor(100-((100-@etykieta_3)/20)) #</p>
                <h2>Etykieta 3</h2>
                <p>#RZUĆ}}<strong>{{@etykieta_3}}</strong>{{floor(100-((100-@etykieta_3)/20))}}{{floor(@etykieta_3/5)}}{{floor(@etykieta_3/20)}}</p>
            </td>
            <td style="text-align:center">Gadanina</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@gadanina)df&gt;floor(100-((100-@gadanina)/20)) #</p>
                <h2>Gadanina</h2>
                <p>#RZUĆ}}<strong>{{@gadanina}}</strong>{{floor(100-((100-@gadanina)/20))}}{{floor(@gadanina/5)}}{{floor(@gadanina/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Hazard</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@hazard)df&gt;floor(100-((100-@hazard)/20)) #</p>
                <h2>Hazard</h2>
                <p>#RZUĆ}}<strong>{{@hazard}}</strong>{{floor(100-((100-@hazard)/20))}}{{floor(@hazard/5)}}{{floor(@hazard/20)}}</p>
            </td>
            <td style="text-align:center">Hipnoza</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@hipnoza)df&gt;floor(100-((100-@hipnoza)/20)) #</p>
                <h2>Hipnoza</h2>
                <p>#RZUĆ}}<strong>{{@hipnoza}}</strong>{{floor(100-((100-@hipnoza)/20))}}{{floor(@hipnoza/5)}}{{floor(@hipnoza/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Jeździectwo</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@jezdziectwo)df&gt;floor(100-((100-@jezdziectwo)/20)) #</p>
                <h2>Jeździectwo</h2>
                <p>#RZUĆ}}<strong>{{@jezdziectwo}}</strong>{{floor(100-((100-@jezdziectwo)/20))}}{{floor(@jezdziectwo/5)}}{{floor(@jezdziectwo/20)}}</p>
            </td>
            <td style="text-align:center">Język Ojczysty</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@jezyk_ojczysty)df&gt;floor(100-((100-@jezyk_ojczysty)/20)) #</p>
                <h2>Język Ojczysty</h2>
                <p>#RZUĆ}}<strong>{{@jezyk_ojczysty}}</strong>{{floor(100-((100-@jezyk_ojczysty)/20))}}{{floor(@jezyk_ojczysty/5)}}{{floor(@jezyk_ojczysty/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Język 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@jezyk_2)df&gt;floor(100-((100-@jezyk_2)/20)) #</p>
                <h2>Język 2</h2>
                <p>#RZUĆ}}<strong>{{@jezyk_2}}</strong>{{floor(100-((100-@jezyk_2)/20))}}{{floor(@jezyk_2/5)}}{{floor(@jezyk_2/20)}}</p>
            </td>
            <td style="text-align:center">Kuglarstwo</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@kuglarstwo)df&gt;floor(100-((100-@kuglarstwo)/20)) #</p>
                <h2>Kuglarstwo</h2>
                <p>#RZUĆ}}<strong>{{@kuglarstwo}}</strong>{{floor(100-((100-@kuglarstwo)/20))}}{{floor(@kuglarstwo/5)}}{{floor(@kuglarstwo/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Medycyna</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@medycyna)df&gt;floor(100-((100-@medycyna)/20)) #</p>
                <h2>Medycyna</h2>
                <p>#RZUĆ}}<strong>{{@medycyna}}</strong>{{floor(100-((100-@medycyna)/20))}}{{floor(@medycyna/5)}}{{floor(@medycyna/20)}}</p>
            </td>
            <td style="text-align:center">Nasłuchiwanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@nasluchiwanie)df&gt;floor(100-((100-@nasluchiwanie)/20)) #</p>
                <h2>Nasłuchiwanie</h2>
                <p>#RZUĆ}}<strong>{{@nasluchiwanie}}</strong>{{floor(100-((100-@nasluchiwanie)/20))}}{{floor(@nasluchiwanie/5)}}{{floor(@nasluchiwanie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Nauczanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@nauczanie)df&gt;floor(100-((100-@nauczanie)/20)) #</p>
                <h2>Nauczanie</h2>
                <p>#RZUĆ}}<strong>{{@nauczanie}}</strong>{{floor(100-((100-@nauczanie)/20))}}{{floor(@nauczanie/5)}}{{floor(@nauczanie/20)}}</p>
            </td>
            <td style="text-align:center">Nauka 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@nauka_1)df&gt;floor(100-((100-@nauka_1)/20)) #</p>
                <h2>Nauka 1</h2>
                <p>#RZUĆ}}<strong>{{@nauka_1}}</strong>{{floor(100-((100-@nauka_1)/20))}}{{floor(@nauka_1/5)}}{{floor(@nauka_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Nauka 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@nauka_2)df&gt;floor(100-((100-@nauka_2)/20)) #</p>
                <h2>Nauka 2</h2>
                <p>#RZUĆ}}<strong>{{@nauka_2}}</strong>{{floor(100-((100-@nauka_2)/20))}}{{floor(@nauka_2/5)}}{{floor(@nauka_2/20)}}</p>
            </td>
            <td style="text-align:center">Nauka 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@nauka_3)df&gt;floor(100-((100-@nauka_3)/20)) #</p>
                <h2>Nauka 3</h2>
                <p>#RZUĆ}}<strong>{{@nauka_3}}</strong>{{floor(100-((100-@nauka_3)/20))}}{{floor(@nauka_3/5)}}{{floor(@nauka_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Nawigacja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@nawigacja)df&gt;floor(100-((100-@nawigacja)/20)) #</p>
                <h2>Nawigacja</h2>
                <p>#RZUĆ}}<strong>{{@nawigacja}}</strong>{{floor(100-((100-@nawigacja)/20))}}{{floor(@nawigacja/5)}}{{floor(@nawigacja/20)}}</p>
            </td>
            <td style="text-align:center">Negocjacje</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@negocjacje)df&gt;floor(100-((100-@negocjacje)/20)) #</p>
                <h2>Negocjacje</h2>
                <p>#RZUĆ}}<strong>{{@negocjacje}}</strong>{{floor(100-((100-@negocjacje)/20))}}{{floor(@negocjacje/5)}}{{floor(@negocjacje/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Obsługa Altyrelii</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@obsluga_altyrelii)df&gt;floor(100-((100-@obsluga_altyrelii)/20)) #</p>
                <h2>Obsługa Altyrelii</h2>
                <p>#RZUĆ}}<strong>{{@obsluga_altyrelii}}</strong>{{floor(100-((100-@obsluga_altyrelii)/20))}}{{floor(@obsluga_altyrelii/5)}}{{floor(@obsluga_altyrelii/20)}}</p>
            </td>
            <td style="text-align:center">Parowanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@parowanie)df&gt;floor(100-((100-@parowanie)/20)) #</p>
                <h2>Parowanie</h2>
                <p>#RZUĆ}}<strong>{{@parowanie}}</strong>{{floor(100-((100-@parowanie)/20))}}{{floor(@parowanie/5)}}{{floor(@parowanie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Persfazja</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@persfazja)df&gt;floor(100-((100-@persfazja)/20)) #</p>
                <h2>Persfazja</h2>
                <p>#RZUĆ}}<strong>{{@persfazja}}</strong>{{floor(100-((100-@persfazja)/20))}}{{floor(@persfazja/5)}}{{floor(@persfazja/20)}}</p>
            </td>
            <td style="text-align:center">Pierwsza Pomoc</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@pierwsza_pomoc)df&gt;floor(100-((100-@pierwsza_pomoc)/20)) #</p>
                <h2>Pierwsza Pomoc</h2>
                <p>#RZUĆ}}<strong>{{@pierwsza_pomoc}}</strong>{{floor(100-((100-@pierwsza_pomoc)/20))}}{{floor(@pierwsza_pomoc/5)}}{{floor(@pierwsza_pomoc/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Pływanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@plywanie)df&gt;floor(100-((100-@plywanie)/20)) #</p>
                <h2>Pływanie</h2>
                <p>#RZUĆ}}<strong>{{@plywanie}}</strong>{{floor(100-((100-@plywanie)/20))}}{{floor(@plywanie/5)}}{{floor(@plywanie/20)}}</p>
            </td>
            <td style="text-align:center">Powożenie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@powozenie)df&gt;floor(100-((100-@powozenie)/20)) #</p>
                <h2>Powożenie</h2>
                <p>#RZUĆ}}<strong>{{@powozenie}}</strong>{{floor(100-((100-@powozenie)/20))}}{{floor(@powozenie/5)}}{{floor(@powozenie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Reaserch</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@reaserch)df&gt;floor(100-((100-@reaserch)/20)) #</p>
                <h2>Reaserch</h2>
                <p>#RZUĆ}}<strong>{{@reaserch}}</strong>{{floor(100-((100-@reaserch)/20))}}{{floor(@reaserch/5)}}{{floor(@reaserch/20)}}</p>
            </td>
            <td style="text-align:center">Rzemiosło 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@rzemioslo_1)df&gt;floor(100-((100-@rzemioslo_1)/20)) #</p>
                <h2>Rzemiosło 1</h2>
                <p>#RZUĆ}}<strong>{{@rzemioslo_1}}</strong>{{floor(100-((100-@rzemioslo_1)/20))}}{{floor(@rzemioslo_1/5)}}{{floor(@rzemioslo_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Rzemiosło 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@rzemioslo_2)df&gt;floor(100-((100-@rzemioslo_2)/20)) #</p>
                <h2>Rzemiosło 2</h2>
                <p>#RZUĆ}}<strong>{{@rzemioslo_2}}</strong>{{floor(100-((100-@rzemioslo_2)/20))}}{{floor(@rzemioslo_2/5)}}{{floor(@rzemioslo_2/20)}}</p>
            </td>
            <td style="text-align:center">Rzemiosło 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@rzemioslo_3)df&gt;floor(100-((100-@rzemioslo_3)/20)) #</p>
                <h2>Rzemiosło 3</h2>
                <p>#RZUĆ}}<strong>{{@rzemioslo_3}}</strong>{{floor(100-((100-@rzemioslo_3)/20))}}{{floor(@rzemioslo_3/5)}}{{floor(@rzemioslo_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Rzucanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@rzucanie)df&gt;floor(100-((100-@rzucanie)/20)) #</p>
                <h2>Rzucanie</h2>
                <p>#RZUĆ}}<strong>{{@rzucanie}}</strong>{{floor(100-((100-@rzucanie)/20))}}{{floor(@rzucanie/5)}}{{floor(@rzucanie/20)}}</p>
            </td>
            <td style="text-align:center">Skok</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@skok)df&gt;floor(100-((100-@skok)/20)) #</p>
                <h2>Skok</h2>
                <p>#RZUĆ}}<strong>{{@skok}}</strong>{{floor(100-((100-@skok)/20))}}{{floor(@skok/5)}}{{floor(@skok/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Skradanie się</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@skradanie_sie)df&gt;floor(100-((100-@skradanie_sie)/20)) #</p>
                <h2>Skradanie się</h2>
                <p>#RZUĆ}}<strong>{{@skradanie_sie}}</strong>{{floor(100-((100-@rzskradanie_sie)/20))}}{{floor(@skradanie_sie/5)}}{{floor(@skradanie_sie/20)}}</p>
            </td>
            <td style="text-align:center">Spostrzegawczość</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@spostrzegawczosc)df&gt;floor(100-((100-@spostrzegawczosc)/20)) #</p>
                <h2>Spostrzegawczość</h2>
                <p>#RZUĆ}}<strong>{{@spostrzegawczosc}}</strong>{{floor(100-((100-@spostrzegawczosc)/20))}}{{floor(@spostrzegawczosc/5)}}{{floor(@spostrzegawczosc/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Status</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@status)df&gt;floor(100-((100-@status)/20)) #</p>
                <h2>Status</h2>
                <p>#RZUĆ}}<strong>{{@status}}</strong>{{floor(100-((100-@status)/20))}}{{floor(@status/5)}}{{floor(@status/20)}}</p>
            </td>
            <td style="text-align:center">Stawianie Run</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@stawianie_run)df&gt;floor(100-((100-@stawianie_run)/20)) #</p>
                <h2>Stawianie Run</h2>
                <p>#RZUĆ}}<strong>{{@stawianie_run}}</strong>{{floor(100-((100-@stawianie_run)/20))}}{{floor(@stawianie_run/5)}}{{floor(@stawianie_run/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Strategia</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@strategia)df&gt;floor(100-((100-@strategia)/20)) #</p>
                <h2>Strategia</h2>
                <p>#RZUĆ}}<strong>{{@strategia}}</strong>{{floor(100-((100-@strategia)/20))}}{{floor(@strategia/5)}}{{floor(@strategia/20)}}</p>
            </td>
            <td style="text-align:center">Sztuka 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@sztuka_1)df&gt;floor(100-((100-@sztuka_1)/20)) #</p>
                <h2>Sztuka 1</h2>
                <p>#RZUĆ}}<strong>{{@sztuka_1}}</strong>{{floor(100-((100-@sztuka_1)/20))}}{{floor(@sztuka_1/5)}}{{floor(@sztuka_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Sztuka 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@sztuka_2)df&gt;floor(100-((100-@sztuka_2)/20)) #</p>
                <h2>Sztuka 2</h2>
                <p>#RZUĆ}}<strong>{{@sztuka_2}}</strong>{{floor(100-((100-@sztuka_2)/20))}}{{floor(@sztuka_2/5)}}{{floor(@sztuka_2/20)}}</p>
            </td>
            <td style="text-align:center">Sztuka 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@sztuka_3)df&gt;floor(100-((100-@sztuka_3)/20)) #</p>
                <h2>Sztuka 3</h2>
                <p>#RZUĆ}}<strong>{{@sztuka_3}}</strong>{{floor(100-((100-@sztuka_3)/20))}}{{floor(@sztuka_3/5)}}{{floor(@sztuka_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Sztuka Przetrwania</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@sztuka_przetrwania)df&gt;floor(100-((100-@sztuka_przetrwania)/20)) #</p>
                <h2>Sztuka Przetrwania</h2>
                <p>#RZUĆ}}<strong>{{@sztuka_przetrwania}}</strong>{{floor(100-((100-@sztuka_przetrwania)/20))}}{{floor(@sztuka_przetrwania/5)}}{{floor(@sztuka_przetrwania/20)}}</p>
            </td>
            <td style="text-align:center">Sztuki Walki</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@sztuki_walki)df&gt;floor(100-((100-@sztuki_walki)/20)) #</p>
                <h2>Sztuki Walki</h2>
                <p>#RZUĆ}}<strong>{{@sztuki_walki}}</strong>{{floor(100-((100-@sztuki_walki)/20))}}{{floor(@sztuki_walki/5)}}{{floor(@sztuki_walki/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Tropienie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@tropienie)df&gt;floor(100-((100-@tropienie)/20)) #</p>
                <h2>Tropienie</h2>
                <p>#RZUĆ}}<strong>{{@tropienie}}</strong>{{floor(100-((100-@tropienie)/20))}}{{floor(@tropienie/5)}}{{floor(@tropienie/20)}}</p>
            </td>
            <td style="text-align:center">Ukrywanie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@ukrywanie)df&gt;floor(100-((100-@ukrywanie)/20)) #</p>
                <h2>Ukrywanie</h2>
                <p>#RZUĆ}}<strong>{{@ukrywanie}}</strong>{{floor(100-((100-@ukrywanie)/20))}}{{floor(@ukrywanie/5)}}{{floor(@ukrywanie/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Unik</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@unik)df&gt;floor(100-((100-@unik)/20)) #</p>
                <h2>Unik</h2>
                <p>#RZUĆ}}<strong>{{@unik}}</strong>{{floor(100-((100-@unik)/20))}}{{floor(@unik/5)}}{{floor(@unik/20)}}</p>
            </td>
            <td style="text-align:center">Walka Tarczą</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@walka_tarcza)df&gt;floor(100-((100-@walka_tarcza)/20)) #</p>
                <h2>Walka Tarczą</h2>
                <p>#RZUĆ}}<strong>{{@walka_tarcza}}</strong>{{floor(100-((100-@walka_tarcza)/20))}}{{floor(@walka_tarcza/5)}}{{floor(@walka_tarcza/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wiedza 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wiedza_1)df&gt;floor(100-((100-@wiedza_1)/20)) #</p>
                <h2>Wiedza 1</h2>
                <p>#RZUĆ}}<strong>{{@wiedza_1}}</strong>{{floor(100-((100-@wiedza_1)/20))}}{{floor(@wiedza_1/5)}}{{floor(@wiedza_1/20)}}</p>
            </td>
            <td style="text-align:center">Wiedza 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wiedza_2)df&gt;floor(100-((100-@wiedza_2)/20)) #</p>
                <h2>Wiedza 2</h2>
                <p>#RZUĆ}}<strong>{{@wiedza_2}}</strong>{{floor(100-((100-@wiedza_2)/20))}}{{floor(@wiedza_2/5)}}{{floor(@wiedza_2/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wiedza 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wiedza_3)df&gt;floor(100-((100-@wiedza_3)/20)) #</p>
                <h2>Wiedza 3</h2>
                <p>#RZUĆ}}<strong>{{@wiedza_3}}</strong>{{floor(100-((100-@wiedza_3)/20))}}{{floor(@wiedza_3/5)}}{{floor(@wiedza_3/20)}}</p>
            </td>
            <td style="text-align:center">Wnikliwość</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wnikliwosc)df&gt;floor(100-((100-@wnikliwosc)/20)) #</p>
                <h2>Wnikliwość</h2>
                <p>#RZUĆ}}<strong>{{@wnikliwosc}}</strong>{{floor(100-((100-@wnikliwosc)/20))}}{{floor(@wnikliwosc/5)}}{{floor(@wnikliwosc/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wróżenie</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wrozenie)df&gt;floor(100-((100-@wrozenie)/20)) #</p>
                <h2>Wróżenie</h2>
                <p>#RZUĆ}}<strong>{{@wrozenie}}</strong>{{floor(100-((100-@wrozenie)/20))}}{{floor(@wrozenie/5)}}{{floor(@wrozenie/20)}}</p>
            </td>
            <td style="text-align:center">Wspinaczka</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wspinaczka)df&gt;floor(100-((100-@wspinaczka)/20)) #</p>
                <h2>Wspinaczka</h2>
                <p>#RZUĆ}}<strong>{{@wspinaczka}}</strong>{{floor(100-((100-@wspinaczka)/20))}}{{floor(@wspinaczka/5)}}{{floor(@wspinaczka/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Wycena</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wycena)df&gt;floor(100-((100-@wycena)/20)) #</p>
                <h2>Wycena</h2>
                <p>#RZUĆ}}<strong>{{@wycena}}</strong>{{floor(100-((100-@wycena)/20))}}{{floor(@wycena/5)}}{{floor(@wycena/20)}}</p>
            </td>
            <td style="text-align:center">Występy Publiczne 1</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wystepy_publiczne_1)df&gt;floor(100-((100-@wystepy_publiczne_1)/20)) #</p>
                <h2>Występy Publiczne 1</h2>
                <p>#RZUĆ}}<strong>{{@wystepy_publiczne_1}}</strong>{{floor(100-((100-@wystepy_publiczne_1)/20))}}{{floor(@wystepy_publiczne_1/5)}}{{floor(@wystepy_publiczne_1/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Występy Publiczne 2</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wystepy_publiczne_2)df&gt;floor(100-((100-@wystepy_publiczne_2)/20)) #</p>
                <h2>Występy Publiczne 2</h2>
                <p>#RZUĆ}}<strong>{{@wystepy_publiczne_2}}</strong>{{floor(100-((100-@wystepy_publiczne_2)/20))}}{{floor(@wystepy_publiczne_2/5)}}{{floor(@wystepy_publiczne_2/20)}}</p>
            </td>
            <td style="text-align:center">Występy Publiczne 3</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@wystepy_publiczne_3)df&gt;floor(100-((100-@wystepy_publiczne_3)/20)) #</p>
                <h2>Występy Publiczne 3</h2>
                <p>#RZUĆ}}<strong>{{@wystepy_publiczne_3}}</strong>{{floor(100-((100-@wystepy_publiczne_3)/20))}}{{floor(@wystepy_publiczne_3/5)}}{{floor(@wystepy_publiczne_3/20)}}</p>
            </td>
        </tr>
        <tr>
            <td style="text-align:center">Zmysły</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@zmysly)df&gt;floor(100-((100-@zmysly)/20)) #</p>
                <h2>Zmysły</h2>
                <p>#RZUĆ}}<strong>{{@zmysly}}</strong>{{floor(100-((100-@zmysly)/20))}}{{floor(@zmysly/5)}}{{floor(@zmysly/20)}}</p>
            </td>
            <td style="text-align:center">Zręczne Palce</td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@zreczne_palce)df&gt;floor(100-((100-@zreczne_palce)/20)) #</p>
                <h2>Zręczne Palce</h2>
                <p>#RZUĆ}}<strong>{{@zreczne_palce}}</strong>{{floor(100-((100-@zreczne_palce)/20))}}{{floor(@zreczne_palce/5)}}{{floor(@zreczne_palce/20)}}</p>
            </td>
        </tr>
    </tbody>
</table>
<table>
    <tbody>
        <tr>
            <th>Bonusy</th>
            <th>Broń runiczna</th>
            <th>Wzm. Broń runiczna</th>
            <th>Tatuaże Runiczne</th>
            <th>Mięso Demonów</th>
        </tr>
        <tr>
            <th style="text-align:center">MO</th>
            <td style="text-align:center">{{@bron_runiczna_mo}}</td>
            <td style="text-align:center">{{@mieso_mo}}</td>
            <td style="text-align:center">{{@tatuaze_runiczne_mo}}</td>
            <td style="text-align:center">{{@wzm_bron_runiczna_mo}}</td>
        </tr>
        <tr>
            <th style="text-align:center">Unik</th>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@unik_br)df&gt;floor(100-((100-@unik_br)/20)) #</p>
                <p></p>
                <h2>Unik (Broń Runiczna)</h2>
                <p>#UNIK}}<br><strong>{{@unik_br}}</strong>{{floor(100-((100-@unik_br)/20))}}{{floor(@unik_br/5)}}{{floor(@unik_br/20)}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@unik_wbr)df&gt;floor(100-((100-@unik_wbr)/20)) #</p>
                <p></p>
                <h2>Unik (Wzmocniona Broń Runiczna)</h2>
                <p>#UNIK}}<br><strong>{{@unik_wbr}}</strong>{{floor(100-((100-@unik_wbr)/20))}}{{floor(@unik_wbr/5)}}{{floor(@unik_wbr/20)}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@unik_t)df&gt;floor(100-((100-@unik_t)/20)) #</p>
                <p></p>
                <h2>Unik (Tatuaże)</h2>
                <p>#UNIK}}<br><strong>{{@unik_t}}</strong>{{floor(100-((100-@unik_t)/20))}}{{floor(@unik_t/5)}}{{floor(@unik_t/20)}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d100cs&lt;=(@unik_m)df&gt;floor(100-((100-@unik_m)/20)) #</p>
                <p></p>
                <h2>Unik (Mięso Demonów)</h2>
                <p>#UNIK}}<br><strong>{{@unik_m}}</strong>{{floor(100-((100-@unik_m)/20))}}{{floor(@unik_m/5)}}{{floor(@unik_m/20)}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">Regen.</th>
            <td style="text-align:center">1PŻ/Tura</td>
            <td style="text-align:center">1PŻ/Tura</td>
            <td style="text-align:center">1K3 PŻ/Tura</td>
            <td style="text-align:center">1K3+1 PŻ/Tura</td>
        </tr>
        <tr>
            <th style="text-align:center">SIŁ</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bron_runiczna_sila)df20 #</p>
                <h2>Test Siły (Broń runiczna)</h2>
                <p>#SIŁ}}{{@bron_runiczna_sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@wzm_bron_runiczna_sila)df20 #</p>
                <h2>Test Siły (Wzmocniona broń runiczna)</h2>
                <p>#SIŁ}}{{@wzm_bron_runiczna_sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@tatuaze_runiczne_sila)df20 #</p>
                <h2>Test Siły (Tatuaże)</h2>
                <p>#SIŁ}}{{@tatuaze_runiczne_sila}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@mieso_sila)df20 #</p>
                <h2>Test Siły (Mięso Demonów)</h2>
                <p>#SIŁ}}{{@mieso_sila}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">KON</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bron_runiczna_kondycja)df20 #</p>
                <h2>Test Kondycji (Broń runiczna)</h2>
                <p>#KON}}{{@bron_runiczna_kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@wzm_bron_runiczna_kondycja)df20 #</p>
                <h2>Test Kondycji (Wzmocniona Broń runiczna)</h2>
                <p>#KON}}{{@wzm_bron_runiczna_kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@tatuaze_runiczne_kondycja)df20 #</p>
                <h2>Test Kondycji (Tatuaże)</h2>
                <p>#KON}}{{@tatuaze_runiczne_kondycja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@mieso_kondycja)df20 #</p>
                <h2>Test Kondycji (Mięso Demonów)</h2>
                <p>#KON}}{{@mieso_kondycja}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">ZR</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bron_runiczna_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Broń runiczna)</h2>
                <p>#ZR}}{{@bron_runiczna_zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@wzm_bron_runiczna_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Wzmocniona Broń runiczna)</h2>
                <p>#ZR}}{{@wzm_bron_runiczna_zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@tatuaze_runiczne_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Tatuaże)</h2>
                <p>#ZR}}{{@tatuaze_runiczne_zrecznosc}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@mieso_zrecznosc)df20 #</p>
                <h2>Test Zręczności (Mięso Demonów)</h2>
                <p>#ZR}}{{@mieso_zrecznosc}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">OGŁ</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bron_runiczna_oglada)df20 #</p>
                <h2>Test Ogłady (Broń runiczna)</h2>
                <p>#OGŁ}}{{@bron_runiczna_oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@wzm_bron_runiczna_tatuaze_oglada)df20 #</p>
                <h2>Test Ogłady (Wzmocniona Broń runiczna)</h2>
                <p>#OGŁ}}{{@wzm_bron_runiczna_tatuaze_oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@wzm_bron_runiczna_tatuaze_oglada)df20 #</p>
                <h2>Test Ogłady (Tatuaże)</h2>
                <p>#OGŁ}}{{@wzm_bron_runiczna_tatuaze_oglada}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@mieso_oglada)df20 #</p>
                <h2>Test Ogłady (Mięso Demonów)</h2>
                <p>#OGŁ}}{{@mieso_oglada}}</p>
            </td>
        </tr>
        <tr>
            <th style="text-align:center">INT</th>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bron_runiczna_wzm_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Broń runiczna)</h2>
                <p>#INT}}{{@bron_runiczna_wzm_inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@bron_runiczna_wzm_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Wzmocniona Broń runiczna)</h2>
                <p>#INT}}{{@bron_runiczna_wzm_inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@tatuaze_runiczne_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Tatuaże)</h2>
                <p>#INT}}{{@tatuaze_runiczne_inteligencja}}</p>
            </td>
            <td style="text-align:center">
                <p>{{/r d20cs&lt;=(@mieso_inteligencja)df20 #</p>
                <h2>Test Inteligencji (Mięso Demonów)</h2>
                <p>#INT}}{{@mieso_inteligencja}}</p>
            </td>
        </tr>
    </tbody>
</table>
